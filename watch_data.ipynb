# %%
import pandas as pd

# %% [markdown]
# # Task 1 - Conceptual Data Pipeline Planing (max. 10-15 min)

# %% [markdown]
# # Task 2 - Data Exploration and Validation (max. 10-15 min)
#
# Below you find a simulated data set from smart watches and it is your job to validate the data so you can let the clinicians now if they need to talk to the patients and make sure further measurements are better. How would you do that?
# Look at the data for a minute or two, decide on one function and write it (max. 10-15 min). Either explain your thought process while coding or - if it is easier - afterward.
#
# You can use any online aid available as you would in normal coding.

# %%
df = pd.read_csv('data/apple_watch_patients_cleaned.csv')

# %%
df
# Out:
#       patient_id gender  age        date  resting_heart_rate  km_walked  \
# 0              1      M   49  2025-01-01                72.3       6.69
# 1              1      M   49  2025-01-02                71.7       2.57
# 2              1      M   49  2025-01-03                80.5       7.65
# 3              1      M   49  2025-01-04                60.5       3.50
# 4              1      M   49  2025-01-05                58.7       6.54
# ...          ...    ...  ...         ...                 ...        ...
# 1789         200      M   53  2025-01-06                83.6       5.05
# 1790         200      M   53  2025-01-07                77.4       5.10
# 1791         200      M   53  2025-01-08                76.4       7.16
# 1792         200      M   53  2025-01-09                66.7       1.55
# 1793         200      M   53  2025-01-10                82.1       4.93
#
#       oxygen_saturation
# 0                   NaN
# 1                   NaN
# 2                  97.7
# ...
